# %%
def generate_embed_code(youtube_links_str):
    # Split the string by new lines to get individual links
    youtube_links = youtube_links_str.splitlines()
    
    embed_template = '''<iframe width="560" height="315" src="{}" loading="lazy" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>\n'''

    for link in youtube_links:
        # Clean the link by stripping any leading or trailing whitespace
        link = link.strip()

        # Extract the video ID based on the format
        if "youtube.com/watch?v=" in link:
            video_id = link.split("v=")[1].split("&")[0]
        elif "youtu.be/" in link:
            video_id = link.split("youtu.be/")[1].split("?")[0]
        else:
            continue
        
        # Generate the embed URL
        embed_url = f"https://www.youtube.com/embed/{video_id}"
        # Print the embed block
        print(embed_template.format(embed_url))

# Example usage with all links as a single string
youtube_links_str = """
https://youtu.be/i0fVEXZw1S0?si=_lOaMQtajVauDM22
https://youtu.be/MqSzaMSrgiI?si=jKJg6tCNmm2k_COl
https://youtu.be/T5SL1onxLvs?si=F0EyBHhTCOxdMN7X
https://www.youtube.com/watch?v=FfuffT-VP7Q&t=41s  
https://youtu.be/dyDwrvR7jFA?si=zMfSx9DeqtP1_-vX
https://youtu.be/XiBLE_TThqo?si=70YPczDwcSamONJY
https://www.youtube.com/watch?v=Zy4fQQPykcw&t=606s  
https://www.youtube.com/watch?v=jhnVaCNtpkg  
https://youtu.be/f_pfs-6eY7I?si=xdnraRDO0JbTECuK
https://www.youtube.com/watch?v=qqjBwDPN0c8  
https://www.youtube.com/watch?v=jDdRvzKRtLU  
https://www.youtube.com/watch?v=yaDniCeJnos&t=673s  
https://www.youtube.com/watch?v=gNIasHCqguY  
https://www.youtube.com/watch?v=lHljUjfkE8w  
https://www.youtube.com/watch?v=9qRZkuQGHRo&t=3s  
https://www.youtube.com/watch?v=0t3dQZd21yc  
https://www.youtube.com/watch?v=fmeOmaAgL98  
https://www.youtube.com/watch?v=KS1TSTMrJvU&t=462s  
https://www.youtube.com/watch?v=-QsmH6mn880  
https://www.youtube.com/watch?v=vPjGuwtn1TU&t=446s  
https://www.youtube.com/watch?v=SbQjt7AKcJ8  
https://www.youtube.com/watch?v=s-blGAPDrg4  
https://www.youtube.com/watch?v=I6uBQY_vjuE  
https://www.youtube.com/watch?v=NuwJBX1lysI  
https://www.youtube.com/watch?v=3f3VKNx7yxA  
https://www.youtube.com/watch?v=7pL8mLH8C6c  
https://www.youtube.com/watch?v=RkMCADQwU-k  
https://www.youtube.com/watch?v=S4iWqJz71_E&t=206s  
https://www.youtube.com/watch?v=BbVYZpT4sx0  
https://www.youtube.com/watch?v=jUyyed7kemY  
https://www.youtube.com/watch?v=CsCoE2HeRj0&t=10s  
https://www.youtube.com/watch?v=2FjtSYkuxfc&t=23s  
https://www.youtube.com/watch?v=8i1JumShIfY
"""

generate_embed_code(youtube_links_str)

# %%
def generate_image_code():
    for i in range(1, 165):
        # Generate the image tag
        img = f'<img src="Images/war{i}.jpeg" alt="War image {i}">\n'
        # Print the image tag
        print(img)

# Call the function
generate_image_code()

# %%
from bs4 import BeautifulSoup

# Input HTML
html_content = '''
<iframe width="100%" height="300" scrolling="no" frameborder="no"  src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/1864612836&color=%23ff5500&auto_play=true&hide_related=false&show_comments=true&show_user=true&show_reposts=false&show_teaser=true&visual=true" ></iframe><div style="font-size: 10px; color: #cccccc;line-break: anywhere;word-break: normal;overflow: hidden;white-space: nowrap;text-overflow: ellipsis; font-family: Interstate,Lucida Grande,Lucida Sans Unicode,Lucida Sans,Garuda,Verdana,Tahoma,sans-serif;font-weight: 100;"><a href="https://soundcloud.com/warmachine-842136817" title="warmachine" target="_blank" style="color: #cccccc; text-decoration: none;">warmachine</a> · <a href="https://soundcloud.com/warmachine-842136817/necromancy-demo" title="Necromancy demo" target="_blank" style="color: #cccccc; text-decoration: none;">Necromancy demo</a></div>
<iframe width="100%" height="300" scrolling="no" frameborder="no"  src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/
color=%23ff5500&auto_play=true&hide_related=false&show_comments=true&show_user=true&show_reposts=false&show_teaser=true&visual=true"></iframe><div style="font-size: 10px; color: #cccccc;line-break: anywhere;word-break: normal;overflow: hidden;white-space: nowrap;text-overflow: ellipsis; font-family: Interstate,Lucida Grande,Lucida Sans Unicode,Lucida Sans,Garuda,Verdana,Tahoma,sans-serif;font-weight: 100;"><a href="https://soundcloud.com/lex-rigby" title="lex" target="_blank" style="color: #cccccc; text-decoration: none;">lex</a> · <a href="https://soundcloud.com/lex-rigby/srry4leavin" title="srry4leavin" target="_blank" style="color: #cccccc; text-decoration: none;">srry4leavin</a></div>
<iframe width="100%" height="300" scrolling="no" frameborder="no"  src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/1614905067&color=%23ff5500&auto_play=true&hide_related=false&show_comments=true&show_user=true&show_reposts=false&show_teaser=true&visual=true"></iframe><div style="font-size: 10px; color: #cccccc;line-break: anywhere;word-break: normal;overflow: hidden;white-space: nowrap;text-overflow: ellipsis; font-family: Interstate,Lucida Grande,Lucida Sans Unicode,Lucida Sans,Garuda,Verdana,Tahoma,sans-serif;font-weight: 100;"><a href="https://soundcloud.com/lex-rigby" title="lex" target="_blank" style="color: #cccccc; text-decoration: none;">lex</a> · <a href="https://soundcloud.com/lex-rigby/symphonia-ix-cover" title="symphonia ix cover" target="_blank" style="color: #cccccc; text-decoration: none;">symphonia ix cover</a></div>
<iframe width="100%" height="300" scrolling="no" frameborder="no"  src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/1613989125&color=%23ff5500&auto_play=true&hide_related=false&show_comments=true&show_user=true&show_reposts=false&show_teaser=true&visual=true"></iframe><div style="font-size: 10px; color: #cccccc;line-break: anywhere;word-break: normal;overflow: hidden;white-space: nowrap;text-overflow: ellipsis; font-family: Interstate,Lucida Grande,Lucida Sans Unicode,Lucida Sans,Garuda,Verdana,Tahoma,sans-serif;font-weight: 100;"><a href="https://soundcloud.com/lex-rigby" title="lex" target="_blank" style="color: #cccccc; text-decoration: none;">lex</a> · <a href="https://soundcloud.com/lex-rigby/i-dont-care" title="I Dont Care" target="_blank" style="color: #cccccc; text-decoration: none;">I Dont Care</a></div>
<iframe width="100%" height="300" scrolling="no" frameborder="no"  src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/1609462896&color=%23ff5500&auto_play=true&hide_related=false&show_comments=true&show_user=true&show_reposts=false&show_teaser=true&visual=true"></iframe><div style="font-size: 10px; color: #cccccc;line-break: anywhere;word-break: normal;overflow: hidden;white-space: nowrap;text-overflow: ellipsis; font-family: Interstate,Lucida Grande,Lucida Sans Unicode,Lucida Sans,Garuda,Verdana,Tahoma,sans-serif;font-weight: 100;"><a href="https://soundcloud.com/lex-rigby" title="lex" target="_blank" style="color: #cccccc; text-decoration: none;">lex</a> · <a href="https://soundcloud.com/lex-rigby/policemen-are-bad" title="Policemen are bad" target="_blank" style="color: #cccccc; text-decoration: none;">Policemen are bad</a></div>
<iframe width="100%" height="300" scrolling="no" frameborder="no"  src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/1598862258&color=%23ff5500&auto_play=true&hide_related=false&show_comments=true&show_user=true&show_reposts=false&show_teaser=true&visual=true"></iframe><div style="font-size: 10px; color: #cccccc;line-break: anywhere;word-break: normal;overflow: hidden;white-space: nowrap;text-overflow: ellipsis; font-family: Interstate,Lucida Grande,Lucida Sans Unicode,Lucida Sans,Garuda,Verdana,Tahoma,sans-serif;font-weight: 100;"><a href="https://soundcloud.com/lex-rigby" title="lex" target="_blank" style="color: #cccccc; text-decoration: none;">lex</a> · <a href="https://soundcloud.com/lex-rigby/norah-demo" title="norah (demo)" target="_blank" style="color: #cccccc; text-decoration: none;">norah (demo)</a></div>
<iframe width="100%" height="300" scrolling="no" frameborder="no"  src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/1569526429&color=%23ff5500&auto_play=true&hide_related=false&show_comments=true&show_user=true&show_reposts=false&show_teaser=true&visual=true"></iframe><div style="font-size: 10px; color: #cccccc;line-break: anywhere;word-break: normal;overflow: hidden;white-space: nowrap;text-overflow: ellipsis; font-family: Interstate,Lucida Grande,Lucida Sans Unicode,Lucida Sans,Garuda,Verdana,Tahoma,sans-serif;font-weight: 100;"><a href="https://soundcloud.com/lex-rigby" title="lex" target="_blank" style="color: #cccccc; text-decoration: none;">lex</a> · <a href="https://soundcloud.com/lex-rigby/zapaate" title="zapata (demo)" target="_blank" style="color: #cccccc; text-decoration: none;">zapata (demo)</a></div>
<iframe width="100%" height="300" scrolling="no" frameborder="no"  src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/1554303826&color=%23ff5500&auto_play=true&hide_related=false&show_comments=true&show_user=true&show_reposts=false&show_teaser=true&visual=true"></iframe><div style="font-size: 10px; color: #cccccc;line-break: anywhere;word-break: normal;overflow: hidden;white-space: nowrap;text-overflow: ellipsis; font-family: Interstate,Lucida Grande,Lucida Sans Unicode,Lucida Sans,Garuda,Verdana,Tahoma,sans-serif;font-weight: 100;"><a href="https://soundcloud.com/lex-rigby" title="lex" target="_blank" style="color: #cccccc; text-decoration: none;">lex</a> · <a href="https://soundcloud.com/lex-rigby/synth-sin" title="synth Sin" target="_blank" style="color: #cccccc; text-decoration: none;">synth Sin</a></div>
<iframe width="100%" height="300" scrolling="no" frameborder="no"  src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/1534693885&color=%23ff5500&auto_play=true&hide_related=false&show_comments=true&show_user=true&show_reposts=false&show_teaser=true&visual=true"></iframe><div style="font-size: 10px; color: #cccccc;line-break: anywhere;word-break: normal;overflow: hidden;white-space: nowrap;text-overflow: ellipsis; font-family: Interstate,Lucida Grande,Lucida Sans Unicode,Lucida Sans,Garuda,Verdana,Tahoma,sans-serif;font-weight: 100;"><a href="https://soundcloud.com/lex-rigby" title="lex" target="_blank" style="color: #cccccc; text-decoration: none;">lex</a> · <a href="https://soundcloud.com/lex-rigby/small" title="small" target="_blank" style="color: #cccccc; text-decoration: none;">small</a></div>
<iframe width="100%" height="300" scrolling="no" frameborder="no"  src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/1394566294&color=%23ff5500&auto_play=true&hide_related=false&show_comments=true&show_user=true&show_reposts=false&show_teaser=true&visual=true"></iframe><div style="font-size: 10px; color: #cccccc;line-break: anywhere;word-break: normal;overflow: hidden;white-space: nowrap;text-overflow: ellipsis; font-family: Interstate,Lucida Grande,Lucida Sans Unicode,Lucida Sans,Garuda,Verdana,Tahoma,sans-serif;font-weight: 100;"><a href="https://soundcloud.com/lex-rigby" title="lex" target="_blank" style="color: #cccccc; text-decoration: none;">lex</a> · <a href="https://soundcloud.com/lex-rigby/mars" title="mars" target="_blank" style="color: #cccccc; text-decoration: none;">mars</a></div>
'''

def extract_songs(html):
    soup = BeautifulSoup(html, 'html.parser')
    song_list = []

    # Find all iframes and corresponding divs
    for iframe, div in zip(soup.find_all('iframe'), soup.find_all('div')):
        iframe_src = iframe['src']
        track_url = iframe_src.split('url=')[1].split('&')[0]
        track_id = track_url.split('/')[-1]
        
        # Extract song title from the div
        div_content = div.get_text()
        title = div_content.split('·')[-1].strip()
        
        # Generate list item
        song_list.append(f'<li><a href="#" data-url="{track_url}">Warmachine - {title}</a></li>')

    return f'<ul>\n' + '\n'.join(song_list) + '\n</ul>'

# Extract and print the formatted song list
formatted_song_list = extract_songs(html_content)
print(formatted_song_list)
# Out:
# <ul>
# <li><a href="#" data-url="https%3A//api.soundcloud.com/tracks/1864612836">Warmachine - Necromancy demo</a></li>
# <li><a href="#" data-url="https%3A//api.soundcloud.com/tracks/1850483631">Warmachine - lost to the ether.mp3</a></li>
# <li><a href="#" data-url="https%3A//api.soundcloud.com/tracks/1786304658">Warmachine - if im high demo</a></li>
# <li><a href="#" data-url="https%3A//api.soundcloud.com/tracks/1735216005">Warmachine - holyoke</a></li>
# <li><a href="#" data-url="https%3A//api.soundcloud.com/tracks/1735215576">Warmachine - coolest hell</a></li>
# <li><a href="#" data-url="https%3A//api.soundcloud.com/tracks/1729738548">Warmachine - Desert Level 2</a></li>
# <li><a href="#" data-url="https%3A//api.soundcloud.com/tracks/1685313864">Warmachine - live coolest year in hell</a></li>
# <li><a href="#" data-url="https%3A//api.soundcloud.com/tracks/1634832543">Warmachine - bones (8 track)</a></li>
# ...

# %%
def extract_song_urls(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    song_urls = []

    # Find all iframe elements
    iframes = soup.find_all('iframe')
    for iframe in iframes:
        src = iframe.get('src', '')
        # Extract the SoundCloud track URL from the src attribute
        url_part = src.split('url=')[1].split('&')[0]
        song_urls.append(f'"{url_part}"')

    # Format the song URLs as a JavaScript array
    js_array = 'const songs = [\n    ' + ',\n    '.join(song_urls) + '\n];'
    return js_array
    
js_array = extract_song_urls(html_content)
print(js_array)
# Out:
# const songs = [
#     "https%3A//api.soundcloud.com/tracks/1864612836",
#     "https%3A//api.soundcloud.com/tracks/1850483631",
#     "https%3A//api.soundcloud.com/tracks/1786304658",
#     "https%3A//api.soundcloud.com/tracks/1735216005",
#     "https%3A//api.soundcloud.com/tracks/1735215576",
#     "https%3A//api.soundcloud.com/tracks/1729738548",
#     "https%3A//api.soundcloud.com/tracks/1685313864",
#     "https%3A//api.soundcloud.com/tracks/1634832543",
#     "https%3A//api.soundcloud.com/tracks/1581339979",
#     "https%3A//api.soundcloud.com/tracks/1569521344",
#     "https%3A//api.soundcloud.com/tracks/1899784524",
#     "https%3A//api.soundcloud.com/tracks/1889061285",
#     "https%3A//api.soundcloud.com/tracks/1884278601",
#     "https%3A//api.soundcloud.com/tracks/1865913285",
#     "https%3A//api.soundcloud.com/tracks/1864017993",
#     "https%3A//api.soundcloud.com/tracks/1823348541",
#     "https%3A//api.soundcloud.com/tracks/1740679404",
# ...

# %%
from yt_dlp import YoutubeDL

if __name__ == '__main__':
    video_url = input("Please insert the URL: ")
    video_info = YoutubeDL().extract_info(url=video_url, download=False)
    options = {
        'format': 'bestaudio/best',
        'keepvideo': False,
        'outtmpl': '%(title)s.mp3',
        # 'playlist_items': '2'
    }
    with YoutubeDL(options) as ydl:
        out = ydl.download([video_info['webpage_url']])
# Out:
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=OLAK5uy_kiG8_XUYkMzpUbu3QzzmGG6oCIH2of3xA
# [youtube:tab] OLAK5uy_kiG8_XUYkMzpUbu3QzzmGG6oCIH2of3xA: Downloading webpage
# [youtube:tab] OLAK5uy_kiG8_XUYkMzpUbu3QzzmGG6oCIH2of3xA: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Room Of Lights
# [youtube:tab] Playlist Room Of Lights: Downloading 14 items of 14
# [download] Downloading item 1 of 14
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1s2DSFDKlAA
# [youtube] 1s2DSFDKlAA: Downloading webpage
# [youtube] 1s2DSFDKlAA: Downloading ios player API JSON
# [youtube] 1s2DSFDKlAA: Downloading web creator player API JSON
# [youtube] 1s2DSFDKlAA: Downloading m3u8 information
# [download] Downloading item 2 of 14
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BX5zGX8jdTc
# [youtube] BX5zGX8jdTc: Downloading webpage
# [youtube] BX5zGX8jdTc: Downloading ios player API JSON
# ...
